# %%
import numpy as np 
import matplotlib.pyplot as plt

Volt_measured_Polarizer = np.array([.3, .9, 2, 3.7, 5.8, 9.3, 14.7, 18.5, 22.4, 30.4, 35.4, 37, 41.6, 47.5, 49.6, 51.9, 53.7, 53.2, 56.7, 53, 58.8, 61.5, 53.8, 49, 45.9, 37.5, 29.1, 28, 25.2, 19.5, 15.6, 10.2, 7.5, 4.2, 2.1, .7, .1, .6, 1.7, 4.2, 6.5, 9.3, 15.1, 18.6, 25.3, 19.3, 34.4, 43.3, 51.8, 52.1, 58.9, 63.6, 61.2, 62.7, 58.2, 64.6, 65.6, 61.4, 54.9, 51.8, 53.3, 47, 39.6, 32.6, 25.7, 23.7, 15.8, 11.7, 7.9, 4.6, 2.1, .9])
angles = np.arange(0, 360, 5)
plt.figure(figsize=(10, 6))

# Plot measured voltages
plt.plot(angles, Volt_measured_Polarizer, 'bo-', label='Measured Voltage')

# Fit cos^2(theta) to the data by scaling and shifting
# Estimate amplitude and offset
amplitude = np.max(Volt_measured_Polarizer) - np.min(Volt_measured_Polarizer)
offset = np.min(Volt_measured_Polarizer)
sin2_fit = offset + amplitude * np.sin(np.deg2rad(angles))**2

# Plot cos^2(theta) fit
plt.plot(angles, sin2_fit, color='gray', linestyle='--', linewidth=2, alpha=0.5, label=r'Fitted $A\cos^2(\theta) + B$')

plt.xlabel('Angle (degrees)')
plt.ylabel('Voltage (V)')
plt.title('Measured Voltage with Analyzer vs Angle with Cos² Fit(Shifted and Scaled for alignment)')
plt.legend()
plt.grid(True)
plt.savefig('Polarizer_Variation.png')
plt.show()

# %%
import numpy as np 
import matplotlib.pyplot as plt

Volt_measured_HWP = np.array([4.7, 9.2, 13.6, 19.4, 25, 28.2, 31.1, 30.1, 29.3, 26.3, 23, 17.1, 10.9, 6, 2.7, .7, .1, 1.9, 5, 8.6, 14.9, 21.8, 24.5, 30.6, 34.2, 35, 34.2, 29.3, 24.1, 19.3, 13.4, 7.7, 3.6, .9, .2, 1.7, 5, 9.2, 16.3, 22, 28.4, 33.3, 34.1, 34.6, 31, 27.3, 22.9, 17.5, 13, 7.1, 3.3, 1.2, .4, .2, 4.7, 9.6, 16.7, 22.1, 26.8, 30.1, 34.7, 32.7, 31, 28.8, 23.4, 16.5, 10.6, 5.6, 2.4, .6, .3, 1.6])
angles = np.arange(0, 360, 5)
plt.figure(figsize=(10, 6))

# Plot measured voltages
plt.plot(angles, Volt_measured_HWP, 'bo-', label='Measured Voltage')

# Fit cos^2(theta) to the data by scaling and shifting
# Estimate amplitude and offset
amplitude = np.max(Volt_measured_HWP) - np.min(Volt_measured_HWP)
offset = np.min(Volt_measured_HWP)
sin2_fit = offset + amplitude * np.sin(2*np.deg2rad(angles)+.37)**2

# Plot cos^2(theta) fit
plt.plot(angles, sin2_fit, color='gray', linestyle='--', linewidth=2, alpha=0.5, label=r'Fitted $A\cos^2(\theta) + B$')

plt.xlabel('Angle (degrees)')
plt.ylabel('Voltage (V)')
plt.title('Measured Voltage with HWP vs Angle with Cos²(2theta) Fit(Shifted and Scaled for alignment)')
plt.legend()
plt.grid(True)
plt.savefig('HWP_Variation.png')
plt.show()

# %%
import numpy as np 
import matplotlib.pyplot as plt

Volt_measured_QWP = np.array([3.3, 5.4, 7.5, 10.8, 12.9, 14, 13.8, 13.5, 13.8, 12.3, 10.4, 7.7, 4.6, 2.8, 1.4, .4, .3, 1, 2.3, 4.5, 6.7, 10, 12.7, 15.1, 16.8, 17.9, 17.2, 15.4, 12.5, 8.7, 6, 3.5, 1.6, .5, .3, 1.1, 3.5, 6.3, 10.1, 13.8, 17.2, 20.4, 21.3, 22.4, 21, 18.4, 15.6, 12.1, 7.6, 4.7, 2.2, .4, .3, 1.9, 4.3, 7.2, 10.6, 13.2, 16.5, 16, 16.8, 19.6, 17.5, 16.3, 13.1, 9.2, 6.1, 3.2, 1.5, .4, .3, 1.5])
angles = np.arange(0, 360, 5)
plt.figure(figsize=(10, 6))

# Plot measured voltages
plt.plot(angles, Volt_measured_QWP, 'bo-', label='Measured Voltage')

# Fit cos^2(theta) to the data by scaling and shifting
# Estimate amplitude and offset
amplitude = np.max(Volt_measured_QWP) - np.min(Volt_measured_QWP)
offset = np.min(Volt_measured_QWP)
sin2_fit = offset + amplitude * np.sin(2*np.deg2rad(angles)+3.5)**2

# Plot cos^2(theta) fit
plt.plot(angles, sin2_fit, color='gray', linestyle='--', linewidth=2, alpha=0.5, label=r'Fitted $A\cos^2(\theta) + B$')

plt.xlabel('Angle (degrees)')
plt.ylabel('Voltage (V)')
plt.title('Measured Voltage with QWP vs Angle with Cos² Fit(Shifted and Scaled for alignment)')
plt.legend()
plt.grid(True)
plt.savefig('QWP_Variation.png')
plt.show()
