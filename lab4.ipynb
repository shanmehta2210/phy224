# %%
import numpy as np
import matplotlib.pyplot as plt
Volt_measured_Linear = np.array([.8, .6, .4, .2, .1, .1, .3, .5, .9, 1.4, 1.4, 1.5, 1.9, 2.3, 2.4, 7.5, 8.5, 5.4, 1, .3, .2, .2, .1, .2, .7, 1.7, 3, 4.1, 5.5, 7.4, 8.3, 9.2, 10.4, 10.6, 3.4, .3, .2, .1, .1, .2, .2, .3, .4, .5, .7, 1.2, 1.6, 1.8, 2, 1.8, 1.6, 1.3, .8, .5, .3, .2, .2, .1, .1, .2, .3, .3, .4, .4, .5, .6, .7, .9, 1.4, 1.5, 1.2, 1])
angles = np.arange(0, 360, 5)
plt.figure(figsize=(10, 6))
plt.plot(angles, Volt_measured_Linear, 'bo-', label='Measured Voltage')

# Mark the 5th element (index 4, since Python is zero-indexed)
highlight_index = 4
highlight_angle = angles[highlight_index]
highlight_voltage = Volt_measured_Linear[highlight_index]
plt.plot(highlight_angle, highlight_voltage, 'ro', markersize=10)
plt.text(highlight_angle, highlight_voltage + 0.2, f'{highlight_angle}°', color='red', ha='center')

plt.xlabel('Angle (degrees)')
plt.ylabel('Voltage (V)')
plt.title('Measured Voltage vs Angle (Linear)')
plt.grid(True)
plt.legend()
plt.show()
plt.savefig('Measured_Voltage_vs_Angle_Linear.png')

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1.inset_locator import inset_axes

# Main (zoomed-in) data
Voltage_Measured_Dip_1 = np.array([2.1, 1.8, 1.6, 1.3, 1.1, .8, .6, .3, .2, .2, .1, .2, .2, .3, .5, .7, .8, 1.1, 1.3, 1.7])
angles_dip = np.arange(333, 353)

# Full-range data (example arrays, replace with your actual data)
Voltage_full = np.array([59.7, 69.4, 62.8, 65.3, 57.6, 54.8, 49.4, 48.6, 45.1, 36.8, 30.2, 24.5, 19.7, 14.8, 9.5, 5.9, 3.3, 1.5, .3, .2, 1.2, 2.9, 6, 9.8, 14.3, 17.2, 22, 27.6, 33.1, 39.3, 43.4, 47.2, 51.7, 53.3, 60.2, 65.3, 68.7, 65.9, 71.1, 65.7])  # your full-range voltage data
angles_full = np.arange(70, 270, 5)  # your full-range angle data

plt.figure(figsize=(8, 5))
plt.plot(angles_dip, Voltage_Measured_Dip_1, 'bo-', label='Measured Voltage (Zoomed)')

# Mark minimum in main plot
min_index = np.argmin(Voltage_Measured_Dip_1)
min_angle = angles_dip[min_index]
min_voltage = Voltage_Measured_Dip_1[min_index]
plt.plot(min_angle, min_voltage, 'ro', markersize=10)
plt.text(min_angle, min_voltage + 0.1, f'{min_angle}°', color='red', ha='center')

plt.xlabel('Angle (degrees)')
plt.ylabel('Voltage (V)')
plt.title('Voltage vs Angle (Dip 1)')
plt.grid(True)
plt.legend()

# Inset with full-range data
ax_inset = inset_axes(plt.gca(), width="40%", height="40%", loc='upper right')
ax_inset.plot(angles_full, Voltage_full, 'go-', label='Full Range')
ax_inset.set_title('Full Range', fontsize=8)
ax_inset.set_xticks([])
ax_inset.set_yticks([])

plt.show()
plt.savefig('Voltage_vs_Angle_Dip1.png')

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1.inset_locator import inset_axes

# Main (zoomed-in) data
Voltage_Measured_Dip_1 = np.array([.5, .3, .2, .1, .4, .5, .8, .9, 2.1])
angles_dip = np.array([345, 350, 351, 352, 353, 354, 355, 356, 360])

# Full-range data (example arrays, replace with your actual data)
Voltage_full = np.array([55, 53.5, 51.3, 50.4, 48.8, 47, 43.6, 39.2, 35.1, 30.9, 25.3, 21, 17.7, 13.8, 9.3, 5.8, 3.4, 1.8, .5, .3, .8, 2.1, 4.1, 7.2, 10.5, 14.7, 18.8, 23.1, 28.4, 33.9, 38.2, 41.4, 48, 49.4, 50.2, 48.5, 47.2, 45.1, 42.2])  # your full-range voltage data
angles_full = np.arange(255, 450, 5)  # your full-range angle data

plt.figure(figsize=(8, 5))
plt.plot(angles_dip, Voltage_Measured_Dip_1, 'bo-', label='Measured Voltage (Zoomed)')

# Mark minimum in main plot
min_index = np.argmin(Voltage_Measured_Dip_1)
min_angle = angles_dip[min_index]
min_voltage = Voltage_Measured_Dip_1[min_index]
plt.plot(min_angle, min_voltage, 'ro', markersize=10)
plt.text(min_angle, min_voltage + 0.1, f'{min_angle}°', color='red', ha='center')

plt.xlabel('Angle (degrees)')
plt.ylabel('Voltage (V)')
plt.title('Voltage vs Angle (Dip 1)')
plt.grid(True)
plt.legend()

# Inset with full-range data
ax_inset = inset_axes(plt.gca(), width="40%", height="40%", loc='upper right')
ax_inset.plot(angles_full, Voltage_full, 'go-', label='Full Range')
ax_inset.set_title('Full Range', fontsize=8)
ax_inset.set_xticks([])
ax_inset.set_yticks([])
plt.savefig('Voltage_vs_Angle_Dip2.png')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1.inset_locator import inset_axes

# Main (zoomed-in) data
Voltage_Measured_Dip_1 = np.array([.8, .4, .3, .2, .1, .3, .4, .6, .6, .8, 1.1])
angles_dip = np.array([165, 170, 171, 172, 173, 174, 175, 176, 177, 178, 180])

# Full-range data (example arrays, replace with your actual data)
Voltage_full = np.array([44.9, 38.4, 42.7, 41.6, 40.5, 39.7, 36.9, 33.5, 29.3, 26, 21.8, 18.2, 13, 8.4, 5.8, 3.5, 2, .8, .4, .4, 1.1, 2.8, 5.6, 8.7, 11.9, 18.2, 20.9, 26.8, 28.3, 32.7, 33.6, 36.1, 41.1, 42.3, 43.1, 44.9, 52])  # your full-range voltage data
angles_full = np.arange(80, 265, 5)  # your full-range angle data

plt.figure(figsize=(8, 5))
plt.plot(angles_dip, Voltage_Measured_Dip_1, 'bo-', label='Measured Voltage (Zoomed)')

# Mark minimum in main plot
min_index = np.argmin(Voltage_Measured_Dip_1)
min_angle = angles_dip[min_index]
min_voltage = Voltage_Measured_Dip_1[min_index]
plt.plot(min_angle, min_voltage, 'ro', markersize=10)
plt.text(min_angle, min_voltage + 0.1, f'{min_angle}°', color='red', ha='center')

plt.xlabel('Angle (degrees)')
plt.ylabel('Voltage (V)')
plt.title('Voltage vs Angle (Dip 1)')
plt.grid(True)
plt.legend()

# Inset with full-range data
ax_inset = inset_axes(plt.gca(), width="40%", height="40%", loc='upper right')
ax_inset.plot(angles_full, Voltage_full, 'go-', label='Full Range')
ax_inset.set_title('Full Range', fontsize=8)
ax_inset.set_xticks([])
ax_inset.set_yticks([])
plt.savefig('Voltage_vs_Angle_Dip3.png')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

voltage_measured_circular = np.array([14.5, 14.8, 13.5, 13.7, 13.2, 13.6, 14.1, 13.7, 13.6, 14.8, 15, 14.7, 14.4, 14.5, 13.8, 14.4, 14.7, 14.1, 13.8, 14.2, 14.5, 13.9, 14.9, 15.1, 14.7, 14.3, 13.8, 14.4, 14.7, 13.7, 14.1, 14.5, 14.4, 14.3, 13.9, 14.5])
angles = np.arange(0, 360, 10)

plt.figure(figsize=(8, 5))
plt.plot(angles, voltage_measured_circular, 'bo-', label='Measured Voltage')
plt.xlabel('Angle (degrees)')
plt.ylabel('Voltage (V)')
plt.title('Measured Voltage vs Angle (Circular)')
plt.ylim(0, 25)
plt.grid(True)
plt.legend()
plt.savefig('Measured_Voltage_vs_Angle_Circular.png')
plt.show()
