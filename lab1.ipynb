# %% [markdown]
# Yo, this repo is gonna be used to graph shit out for 224

# %%
import matplotlib.pyplot as plt
import numpy as np
time_minutes = np.arange(1, 31)
volt_readings = np.array([39.3, 40, 40.5, 40.8, 41.1, 41.5, 41.5, 41.6, 41.9, 41.9, 42.1, 42.2, 42.5, 42.6, 42.7, 42.7, 42.8, 43.2, 43.1, 42.8, 42.7, 42.9, 42.9, 42.7, 42.8, 43.3, 42.9, 42.8, 43.1, 42.9])
plt.figure(figsize=(10, 5))
plt.plot(time_minutes, volt_readings, marker='o', linestyle='-', color='b', label='Voltage Readings')
plt.title('Voltage Readings Over Time') 
plt.xlabel('Time (minutes)')
plt.ylabel('Voltage (mV)')
plt.savefig('Voltage Readings Over Time.png')  # Save the figure as a PNG file
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
time_minutes = np.arange(1, 31)
volt_readings_polarized = np.array([6.9, 7.1, 7.5, 7.4, 7.5, 7.4, 7.7, 7.4, 7.2, 7.1, 7, 7.1, 7.3, 7.1, 7.1, 6.9, 7.1, 7.2, 7.3, 7.4, 7.3, 7.4, 7.5, 7.3, 7.3, 7.4, 7.5, 7.5, 7.6, 7.5])
plt.figure(figsize=(10, 5))
plt.plot(time_minutes, volt_readings_polarized, marker='o', linestyle='-', color='b', label='Voltage Readings')
plt.title('Polarized Voltage Readings Over Time') 
plt.xlabel('Time (minutes)')
plt.ylabel('Voltage (mV) when polarized')
plt.savefig('Polarized Voltage Readings Over Time.png')  # Save the figure as a PNG file
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
volt_readings_15 = np.array([58.2, 58, 57.8, 57.6, 57.4, 57, 51.3, 48.3, 43.8, 39.4, 32.9, 26.5, 22.9, 18.4, 13.4, 10.2, 8.6, 3.2, 2.6, 2.2, 2, 1.7, 1.4, 1]) 
razor_edge_dist_15 = np.array([0, .25, .5, .75, .8, .85, .9, .91, .92, .93, .94, .95, .96, .97, .98, .99, 1, 1.05, 1.1, 1.2, 1.35, 1.5, 1.75, 2])
plt.figure(figsize=(10, 5))
plt.plot(razor_edge_dist_15, volt_readings_15, marker='o', linestyle='-', color='b', label='Voltage Readings')
plt.title('Voltage Readings Over Razor Edge Distance at 15 cm') 
plt.xlabel('Razor Edge Distance (mm)')
plt.ylabel('Voltage (mV)')

highlight_indices_15 = [5, 17]  # Change these indices as needed
plt.scatter(razor_edge_dist_15[highlight_indices_15], volt_readings_15[highlight_indices_15], color='red', zorder=5)

# Annotate their razor edge distance above the dot
for idx in highlight_indices_15:
    plt.annotate(f'{razor_edge_dist_15[idx]:.2f}', 
                 (razor_edge_dist_15[idx], volt_readings_15[idx]), 
                 textcoords="offset points", xytext=(0,10), ha='center', color='red')
plt.savefig('Voltage Readings Over Razor Edge Distance at 15 cm.png')  # Save the figure as a PNG file
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
volt_readings_15 = np.array([57.8, 57.7, 57.7, 57.5, 57.2, 57.1, 57, 56.7, 56.2, 56.1, 54.8, 49.9, 44.9, 35.9, 28.8, 26, 18.5, 13.5, 7, 2.6, 1.8, 1.7, 1.5, 1]) 
razor_edge_dist_15 = np.array([0, .25, .5, .75, 1, 1.25, 1.5, 1.75, 2, 2.1, 2.15, 2.2, 2.22, 2.25, 2.27, 2.28, 2.3, 2.32, 2.35, 2.4, 2.45, 2.5, 2.65, 3])
plt.figure(figsize=(10, 5))
plt.plot(razor_edge_dist_15, volt_readings_15, marker='o', linestyle='-', color='b', label='Voltage Readings')
plt.title('Voltage Readings Over Razor Edge Distance at 20 cm') 
plt.xlabel('Voltage (mV)')
plt.ylabel('Razor Edge Distance (mm)')

highlight_indices_15 = [10, 19]  # Change these indices as needed
plt.scatter(razor_edge_dist_15[highlight_indices_15], volt_readings_15[highlight_indices_15], color='red', zorder=5)

# Annotate their razor edge distance above the dot
for idx in highlight_indices_15:
    plt.annotate(f'{razor_edge_dist_15[idx]:.2f}', 
                 (razor_edge_dist_15[idx], volt_readings_15[idx]), 
                 textcoords="offset points", xytext=(0,10), ha='center', color='red')
plt.savefig('Voltage Readings Over Razor Edge Distance at 20 cm.png')  # Save the figure as a PNG file
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
volt_readings_15 = np.array([53.3, 53.2, 53.1, 53, 53, 52.8, 46.9, 43.7, 40, 35, 32, 28.6, 22.8, 19.5, 16.6, 14.0, 11.2, 9.0, 5.4, 3.0, 1.7, 1.2, .9, .5]) 
razor_edge_dist_15 = np.array([0, .25, .5, .75, 1, 1.5, 1.75, 1.77, 1.8, 1.83, 1.85, 1.87, 1.9, 1.92, 1.94, 1.96, 1.98, 2, 2.05, 2.1, 2.15, 2.2, 2.25, 2.5])
plt.figure(figsize=(10, 5))
plt.plot(razor_edge_dist_15, volt_readings_15, marker='o', linestyle='-', color='b', label='Voltage Readings')
plt.title('Voltage Readings Over Razor Edge Distance at 24 cm') 
plt.xlabel('Voltage (mV)')
plt.ylabel('Razor Edge Distance (mm)')

highlight_indices_15 = [5, 19]  # Change these indices as needed
plt.scatter(razor_edge_dist_15[highlight_indices_15], volt_readings_15[highlight_indices_15], color='red', zorder=5)

# Annotate their razor edge distance above the dot
for idx in highlight_indices_15:
    plt.annotate(f'{razor_edge_dist_15[idx]:.2f}', 
                 (razor_edge_dist_15[idx], volt_readings_15[idx]), 
                 textcoords="offset points", xytext=(0,10), ha='center', color='red')
plt.savefig('Voltage Readings Over Razor Edge Distance at 24 cm.png')  # Save the figure as a PNG file
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
volt_readings_15 = np.array([58, 57.9, 57.9, 57.8, 57.6, 57.4, 57, 56, 54.5, 49.5, 45.1, 43, 40.7, 36.3, 34.4, 31.6, 28.8, 22, 16, 10.7, 3.8, 2.5, 2, 1.8]) 
razor_edge_dist_15 = np.array([0, .25, .5, 1, 1.25, 1.5, 1.75, 2, 2.1, 2.2, 2.25, 2.27, 2.3, 2.33, 2.35, 2.37, 2.4, 2.45, 2.5, 2.55, 2.7, 2.8, 2.9, 3])
plt.figure(figsize=(10, 5))
plt.plot(razor_edge_dist_15, volt_readings_15, marker='o', linestyle='-', color='b', label='Voltage Readings')
plt.title('Voltage Readings Over Razor Edge Distance at 5 cm') 
plt.xlabel('Voltage (mV)')
plt.ylabel('Razor Edge Distance (mm)')

highlight_indices_15 = [8, 20]  # Change these indices as needed
plt.scatter(razor_edge_dist_15[highlight_indices_15], volt_readings_15[highlight_indices_15], color='red', zorder=5)

# Annotate their razor edge distance above the dot
for idx in highlight_indices_15:
    plt.annotate(f'{razor_edge_dist_15[idx]:.2f}', 
                 (razor_edge_dist_15[idx], volt_readings_15[idx]), 
                 textcoords="offset points", xytext=(0,10), ha='center', color='red')
plt.savefig('Voltage Readings Over Razor Edge Distance at 5 cm.png')  # Save the figure as a PNG file
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
volt_readings_15 = np.array([59.6, 59.5, 59.4, 59.3, 59.1, 58.9, 58.9, 58.8, 58.7, 58.7, 58.1, 57.7, 56.6, 53.7, 47.5, 43.6, 37.3, 30.6, 25.7, 19.6, 16, 9, 2.5, 1.9]) 
razor_edge_dist_15 = np.array([0, .25, .5, .75, 1, 1.25, 1.5, 1.75, 2, 3, 3.25, 3.3, 3.35, 3.4, 3.45, 3.47, 3.5, 3.53, 3.55, 3.58, 3.6, 3.7, 3.85, 4])
plt.figure(figsize=(10, 5))
plt.plot(razor_edge_dist_15, volt_readings_15, marker='o', linestyle='-', color='b', label='Voltage Readings')
plt.title('Voltage Readings Over Razor Edge Distance at 8 cm') 
plt.xlabel('Voltage (mV)')
plt.ylabel('Razor Edge Distance (mm)')

highlight_indices_15 = [10, 21]  # Change these indices as needed
plt.scatter(razor_edge_dist_15[highlight_indices_15], volt_readings_15[highlight_indices_15], color='red', zorder=5)

# Annotate their razor edge distance above the dot
for idx in highlight_indices_15:
    plt.annotate(f'{razor_edge_dist_15[idx]:.2f}', 
                 (razor_edge_dist_15[idx], volt_readings_15[idx]), 
                 textcoords="offset points", xytext=(0,10), ha='center', color='red')
plt.savefig('Voltage Readings Over Razor Edge Distance at 8 cm.png')  # Save the figure as a PNG file
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import make_interp_spline

dist = np.array([5, 8, 15, 20, 24])
beam_diameter = np.array([.6, .45, .2, .35, .6])
beam_radius = beam_diameter / 2

# Create smooth x values
dist_smooth = np.linspace(dist.min(), dist.max(), 300)
# Fit spline
spline = make_interp_spline(dist, beam_radius, k=2)  # k=2 for quadratic (parabola-like)
beam_radius_smooth = spline(dist_smooth)

plt.figure(figsize=(10, 5))
plt.plot(dist_smooth, beam_radius_smooth, color='b', label='Smooth Beam Radius Curve')
plt.scatter(dist, beam_radius, color='red', label='Original Points')
plt.title('Beam Profile (Smooth Curve)')
plt.xlabel('Distance (cm)')
plt.ylabel('Beam Radius (cm)')
plt.ylim(bottom=0)  # Set y-axis to start at 0
plt.legend()
plt.savefig('Beam Profile Smooth Curve.png')  # Save the figure as a
