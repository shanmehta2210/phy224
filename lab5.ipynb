# %%
import numpy as np
import matplotlib.pyplot as plt
Voltage_2 = np.array([317.3, 310.2, 298.7, 273.3, 245.3, 238.5, 229.4, 215.3, 196.1, 200, 208.8, 224.3, 255.2, 265.4, 286.3, 302.8, 304.3, 307.1, 315.3, 300.4, 273.4, 254.4, 234.5, 213.3, 206.6, 199.8, 207.7, 223.2, 239, 256.6, 268.4, 278.3, 287.9, 276, 258.2, 225.3, 203.6, 189.5, 185.1, 181.8, 185.9, 194.2, 207.6, 210.8, 226.5, 237.4, 244.4, 251.1, 231.8, 222.4, 205.6, 196.3, 166.4, 155.0, 145.3, 146.8, 151, 160.3, 174.4, 183.4, 195.0, 203.1, 204.6, 192.7, 178.1, 170.4, 160.1, 146.5, 120.4, 109.4, 107.7, 109.7, 115.3, 126.9, 135.7, 146, 153.4, 158.2, 161.4, 146.9, 145.8, 131.7, 120.1, 109.3, 102.8, 91.6, 91.0, 93.1, 96.9, 102.0, 111.5, 116.7, 119.4, 121.7, 115.6, 106.7, 101.2, 82.4, 80.3])
distance_2 = distance_2 = np.arange(-300, 681, 10)

plt.figure(figsize=(10, 6))
plt.plot(distance_2, Voltage_2, 'bo-', label='Measured Voltage')
plt.xlabel('Distance')
plt.ylabel('Voltage (V)')
plt.title('Measured Voltage vs Distance')
plt.grid(True)
plt.legend()
plt.savefig('voltage_vs_distance.png')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
Voltage_n = np.array([2.7, 2.8, 2.9, 2.8, 2.8, 2.7, 2.6, 1.7, 1.2, 1.1, .9, 1.3, 1.9, 3.3, 4.7, 5.4, 7.1, 11.9, 14.5, 17.2, 19, 24.3, 26.8, 30.4, 29.2, 29.4, 33.8, 57.2, 92.9, 147.7, 214.8, 282.1, 336.2, 369.8, 387.4, 390.4, 388.2, 383.6, 371.5, 355.8, 335.7, 311.2, 280, 215.1, 148.4, 94.2, 56.1, 39.4, 29.7, 29.5, 30.0, 27.3, 24.2, 20.3, 17.5, 14.7, 12.1, 9.5, 7.4, 5.8, 4.5, 3.4, 2.7, 1.8, 1.5, 1.2, 1, .9, 1, 1.1, 1.3, 1.7, 2, 2.3, 2.5, 2.6, 2.8, 2.8, 2.9, 2.8])
distance_n = np.array([-760, -750, -740, -730, -720, -710, -690, -670, -610, -570, -540, 510, -470, -430, -410, -390, -370, -330, -310, -290, -270, -250, -230, -210, -200, -190, -170, -150, -130, -110, -90, -70, -50, -30, -10, 0, 10, 20, 30, 40, 50, 60, 70, 90, 110, 130, 150, 170, 190, 200, 210, 230, 250, 270, 290, 310, 330, 350, 370, 390, 410, 430, 450, 470, 490, 510, 530, 540, 550, 570, 590, 610, 630, 650, 670, 690, 710, 720, 730, 740])

plt.figure(figsize=(10, 6))
plt.plot(distance_n, Voltage_n, 'bo-', label='Measured Voltage')
plt.xlabel('Distance')
plt.ylabel('Voltage (V)')
plt.title('Measured Voltage vs Distance')
plt.grid(True)
plt.legend()
plt.savefig('voltage_vs_distance_n.png')
plt.show()
